# %%
import numpy as np
from surprise import SVD
from surprise import Dataset
from surprise.model_selection import train_test_split
from surprise import accuracy

# 載入 movielens-100k dataset 第一次會需要下載.
data = Dataset.load_builtin('ml-100k')

# %% [markdown]
# # 矩陣分解 SVD (梯度下降)
# 詳細SVD算法可參考：
# 1. [官方SVD算法介紹](https://surprise.readthedocs.io/en/stable/matrix_factorization.html#surprise.prediction_algorithms.matrix_factorization.SVD)
# 2. [SVD_推薦系統_原理](https://medium.com/data-scientists-playground/svd-%E6%8E%A8%E8%96%A6%E7%B3%BB%E7%B5%B1-%E5%8E%9F%E7%90%86-c72c2e35af9c)

# %%
trainset, testset = train_test_split(data, test_size=.25, random_state=1)

# 演算法這邊使用 SVD 就是矩陣分解的概念 (背後使用隨機梯度下降)
algo = SVD()

algo.fit(trainset)
predictions = algo.test(testset)

# %%
predictions
# Out:
# [Prediction(uid='345', iid='715', r_ui=4.0, est=3.5772293304245646, details={'was_impossible': False}),
#  Prediction(uid='92', iid='998', r_ui=2.0, est=2.779116531521131, details={'was_impossible': False}),
#  Prediction(uid='934', iid='195', r_ui=4.0, est=3.853752046963999, details={'was_impossible': False}),
#  Prediction(uid='586', iid='423', r_ui=2.0, est=3.930263424948401, details={'was_impossible': False}),
#  Prediction(uid='336', iid='383', r_ui=1.0, est=1.9354965040268137, details={'was_impossible': False}),
#  Prediction(uid='654', iid='678', r_ui=4.0, est=2.753347237915239, details={'was_impossible': False}),
#  Prediction(uid='64', iid='511', r_ui=4.0, est=4.332167774221425, details={'was_impossible': False}),
#  Prediction(uid='425', iid='209', r_ui=2.0, est=3.4095324762307695, details={'was_impossible': False}),
#  Prediction(uid='821', iid='132', r_ui=5.0, est=4.682807389427265, details={'was_impossible': False}),
#  Prediction(uid='262', iid='559', r_ui=3.0, est=3.077680270721653, details={'was_impossible': False}),
#  Prediction(uid='894', iid='32', r_ui=4.0, est=3.871841359736268, details={'was_impossible': False}),
#  Prediction(uid='514', iid='200', r_ui=2.0, est=3.5895857624676912, details={'was_impossible': False}),
#  Prediction(uid='699', iid='20', r_ui=4.0, est=3.3924323807925085, details={'was_impossible': False}),
#  Prediction(uid='380', iid='433', r_ui=3.0, est=3.1178942892264567, details={'was_impossible': False}),
#  Prediction(uid='865', iid='328', r_ui=3.0, est=2.394842576265517, details={'was_impossible': False}),
#  Prediction(uid='545', iid='665', r_ui=3.0, est=2.905321640376287, details={'was_impossible': False}),
#  Prediction(uid='450', iid='832', r_ui=2.0, est=3.1306518901523863, details={'was_impossible': False}),
#  Prediction(uid='917', iid='473', r_ui=3.0, est=2.9599803226973473, details={'was_impossible': False}),
#  Prediction(uid='621', iid='420', r_ui=4.0, est=3.642629154300881, details={'was_impossible': False}),
#  Prediction(uid='218', iid='269', r_ui=4.0, est=4.127289382789017, details={'was_impossible': False}),
#  Prediction(uid='234', iid='116', r_ui=2.0, est=3.6522004134585906, details={'was_impossible': False}),
#  Prediction(uid='643', iid='447', r_ui=4.0, est=3.7809712927922905, details={'was_impossible': False}),
#  Prediction(uid='452', iid='491', r_ui=4.0, est=3.543315732456052, details={'was_impossible': False}),
#  Prediction(uid='291', iid='418', r_ui=4.0, est=4.02210332751433, details={'was_impossible': False}),
#  Prediction(uid='911', iid='313', r_ui=2.0, est=3.914898216900781, details={'was_impossible': False}),
#  Prediction(uid='291', iid='924', r_ui=4.0, est=3.755282334087085, details={'was_impossible': False}),
#  Prediction(uid='116', iid='596', r_ui=5.0, est=2.7556334034698593, details={'was_impossible': False}),
#  Prediction(uid='174', iid='571', r_ui=1.0, est=2.6904952395051014, details={'was_impossible': False}),
#  Prediction(uid='833', iid='203', r_ui=5.0, est=3.9125493563443974, details={'was_impossible': False}),
#  Prediction(uid='595', iid='289', r_ui=4.0, est=2.988502906657435, details={'was_impossible': False}),
#  Prediction(uid='313', iid='461', r_ui=3.0, est=3.9588155532690954, details={'was_impossible': False}),
#  Prediction(uid='629', iid='137', r_ui=5.0, est=4.3110155320652, details={'was_impossible': False}),
#  Prediction(uid='796', iid='29', r_ui=3.0, est=2.852850465736159, details={'was_impossible': False}),
#  Prediction(uid='303', iid='1016', r_ui=3.0, est=3.096183773850428, details={'was_impossible': False}),
#  Prediction(uid='589', iid='682', r_ui=4.0, est=3.6159748093582422, details={'was_impossible': False}),
#  Prediction(uid='128', iid='715', r_ui=4.0, est=3.208740120972949, details={'was_impossible': False}),
#  Prediction(uid='566', iid='727', r_ui=4.0, est=3.326462842309576, details={'was_impossible': False}),
#  Prediction(uid='233', iid='91', r_ui=3.0, est=4.11220096563321, details={'was_impossible': False}),
#  Prediction(uid='725', iid='300', r_ui=4.0, est=4.192075545113457, details={'was_impossible': False}),
#  Prediction(uid='346', iid='38', r_ui=3.0, est=3.0696780660301775, details={'was_impossible': False}),
#  Prediction(uid='184', iid='559', r_ui=3.0, est=3.1233021642475816, details={'was_impossible': False}),
#  Prediction(uid='784', iid='307', r_ui=4.0, est=3.7326928148889205, details={'was_impossible': False}),
#  Prediction(uid='207', iid='462', r_ui=3.0, est=3.4672755410684672, details={'was_impossible': False}),
#  Prediction(uid='709', iid='515', r_ui=4.0, est=4.321374310178893, details={'was_impossible': False}),
#  Prediction(uid='537', iid='988', r_ui=1.0, est=1.0491230082613785, details={'was_impossible': False}),
#  Prediction(uid='57', iid='756', r_ui=3.0, est=2.797784056269469, details={'was_impossible': False}),
#  Prediction(uid='758', iid='421', r_ui=4.0, est=3.934695885705496, details={'was_impossible': False}),
#  Prediction(uid='14', iid='519', r_ui=5.0, est=4.223374299129809, details={'was_impossible': False}),
#  Prediction(uid='721', iid='319', r_ui=3.0, est=3.4362325269882437, details={'was_impossible': False}),
#  Prediction(uid='271', iid='487', r_ui=4.0, est=3.928749083780306, details={'was_impossible': False}),
#  Prediction(uid='883', iid='26', r_ui=3.0, est=3.443161668825739, details={'was_impossible': False}),
#  Prediction(uid='758', iid='512', r_ui=5.0, est=4.227633678786111, details={'was_impossible': False}),
#  Prediction(uid='60', iid='633', r_ui=4.0, est=4.236745154359002, details={'was_impossible': False}),
#  Prediction(uid='495', iid='162', r_ui=3.0, est=4.3438644447524055, details={'was_impossible': False}),
#  Prediction(uid='406', iid='661', r_ui=5.0, est=3.8883020829212898, details={'was_impossible': False}),
#  Prediction(uid='449', iid='640', r_ui=5.0, est=3.257809768269323, details={'was_impossible': False}),
#  Prediction(uid='417', iid='1044', r_ui=3.0, est=3.129287847003729, details={'was_impossible': False}),
#  Prediction(uid='394', iid='449', r_ui=3.0, est=3.7293296066263784, details={'was_impossible': False}),
#  Prediction(uid='650', iid='510', r_ui=3.0, est=3.6697632820886503, details={'was_impossible': False}),
#  Prediction(uid='90', iid='17', r_ui=4.0, est=3.885973265844717, details={'was_impossible': False}),
#  Prediction(uid='129', iid='272', r_ui=4.0, est=3.5977587643256927, details={'was_impossible': False}),
#  Prediction(uid='3', iid='337', r_ui=1.0, est=2.701097022758492, details={'was_impossible': False}),
#  Prediction(uid='379', iid='524', r_ui=4.0, est=4.1965007731887205, details={'was_impossible': False}),
#  Prediction(uid='201', iid='334', r_ui=4.0, est=2.816472596156052, details={'was_impossible': False}),
#  Prediction(uid='264', iid='525', r_ui=5.0, est=4.774059077394914, details={'was_impossible': False}),
#  Prediction(uid='293', iid='181', r_ui=3.0, est=3.3024911476242873, details={'was_impossible': False}),
#  Prediction(uid='537', iid='606', r_ui=3.0, est=3.286201288835279, details={'was_impossible': False}),
#  Prediction(uid='393', iid='1314', r_ui=3.0, est=2.953346225911673, details={'was_impossible': False}),
#  Prediction(uid='290', iid='208', r_ui=3.0, est=3.5172741459039827, details={'was_impossible': False}),
#  Prediction(uid='399', iid='28', r_ui=2.0, est=3.748669085743, details={'was_impossible': False}),
#  Prediction(uid='591', iid='275', r_ui=4.0, est=3.7833128935056606, details={'was_impossible': False}),
#  Prediction(uid='774', iid='230', r_ui=2.0, est=2.015014668891773, details={'was_impossible': False}),
#  Prediction(uid='7', iid='634', r_ui=5.0, est=4.106954045018838, details={'was_impossible': False}),
#  Prediction(uid='620', iid='678', r_ui=3.0, est=3.551259037204722, details={'was_impossible': False}),
#  Prediction(uid='59', iid='511', r_ui=5.0, est=4.905135051802259, details={'was_impossible': False}),
#  Prediction(uid='94', iid='603', r_ui=4.0, est=4.395931523259232, details={'was_impossible': False}),
#  Prediction(uid='57', iid='173', r_ui=5.0, est=4.19197402402623, details={'was_impossible': False}),
#  Prediction(uid='907', iid='86', r_ui=5.0, est=5, details={'was_impossible': False}),
#  Prediction(uid='262', iid='367', r_ui=4.0, est=3.183498679693054, details={'was_impossible': False}),
#  Prediction(uid='780', iid='887', r_ui=4.0, est=3.5296546541200016, details={'was_impossible': False}),
#  Prediction(uid='435', iid='672', r_ui=1.0, est=2.8332710662783347, details={'was_impossible': False}),
#  Prediction(uid='659', iid='192', r_ui=4.0, est=4.342329701474791, details={'was_impossible': False}),
#  Prediction(uid='848', iid='393', r_ui=5.0, est=3.674419441757017, details={'was_impossible': False}),
#  Prediction(uid='294', iid='1132', r_ui=4.0, est=3.0991445117122463, details={'was_impossible': False}),
#  Prediction(uid='242', iid='294', r_ui=4.0, est=3.4754576362252725, details={'was_impossible': False}),
#  Prediction(uid='663', iid='763', r_ui=5.0, est=3.611854586060508, details={'was_impossible': False}),
#  Prediction(uid='262', iid='258', r_ui=4.0, est=3.7036911444738645, details={'was_impossible': False}),
#  Prediction(uid='472', iid='1228', r_ui=4.0, est=3.702112723772541, details={'was_impossible': False}),
#  Prediction(uid='527', iid='153', r_ui=5.0, est=3.9198975620242686, details={'was_impossible': False}),
#  Prediction(uid='933', iid='578', r_ui=1.0, est=2.1898263497991324, details={'was_impossible': False}),
#  Prediction(uid='28', iid='800', r_ui=4.0, est=3.027584971228248, details={'was_impossible': False}),
#  Prediction(uid='409', iid='325', r_ui=4.0, est=2.508345286757747, details={'was_impossible': False}),
#  Prediction(uid='339', iid='1404', r_ui=5.0, est=3.4719353330391334, details={'was_impossible': False}),
#  Prediction(uid='58', iid='490', r_ui=4.0, est=4.018303480645991, details={'was_impossible': False}),
#  Prediction(uid='934', iid='423', r_ui=3.0, est=3.95114844789427, details={'was_impossible': False}),
#  Prediction(uid='506', iid='873', r_ui=4.0, est=3.411560749798294, details={'was_impossible': False}),
#  Prediction(uid='274', iid='471', r_ui=4.0, est=4.106223702275993, details={'was_impossible': False}),
#  Prediction(uid='642', iid='369', r_ui=2.0, est=3.6088333377715416, details={'was_impossible': False}),
#  Prediction(uid='422', iid='201', r_ui=4.0, est=3.972325178806373, details={'was_impossible': False}),
#  Prediction(uid='181', iid='222', r_ui=4.0, est=1.6921539987631846, details={'was_impossible': False}),
#  Prediction(uid='32', iid='313', r_ui=4.0, est=3.7489743390002785, details={'was_impossible': False}),
#  Prediction(uid='862', iid='982', r_ui=4.0, est=3.8042738216482483, details={'was_impossible': False}),
#  Prediction(uid='754', iid='9', r_ui=4.0, est=3.92171806585337, details={'was_impossible': False}),
#  Prediction(uid='313', iid='192', r_ui=3.0, est=4.1992191729233195, details={'was_impossible': False}),
#  Prediction(uid='450', iid='332', r_ui=4.0, est=3.663473728917887, details={'was_impossible': False}),
#  Prediction(uid='919', iid='4', r_ui=1.0, est=3.8424969291266864, details={'was_impossible': False}),
#  Prediction(uid='675', iid='891', r_ui=2.0, est=3.4060135450813935, details={'was_impossible': False}),
#  Prediction(uid='216', iid='147', r_ui=4.0, est=3.5970742107893843, details={'was_impossible': False}),
#  Prediction(uid='373', iid='404', r_ui=4.0, est=3.730517213692484, details={'was_impossible': False}),
#  Prediction(uid='922', iid='411', r_ui=1.0, est=2.881594904950378, details={'was_impossible': False}),
#  Prediction(uid='59', iid='168', r_ui=5.0, est=4.929497962879539, details={'was_impossible': False}),
#  Prediction(uid='201', iid='288', r_ui=4.0, est=3.216534455785012, details={'was_impossible': False}),
#  Prediction(uid='727', iid='1224', r_ui=3.0, est=2.3941123706523024, details={'was_impossible': False}),
#  Prediction(uid='201', iid='979', r_ui=2.0, est=2.779117033702973, details={'was_impossible': False}),
#  Prediction(uid='62', iid='318', r_ui=5.0, est=4.219116000389817, details={'was_impossible': False}),
#  Prediction(uid='796', iid='202', r_ui=4.0, est=3.79672558530609, details={'was_impossible': False}),
#  Prediction(uid='835', iid='162', r_ui=5.0, est=4.090918219360718, details={'was_impossible': False}),
#  Prediction(uid='655', iid='288', r_ui=3.0, est=2.247726132499015, details={'was_impossible': False}),
#  Prediction(uid='897', iid='526', r_ui=5.0, est=4.070787616514701, details={'was_impossible': False}),
#  Prediction(uid='719', iid='298', r_ui=2.0, est=3.4574269466463208, details={'was_impossible': False}),
#  Prediction(uid='823', iid='52', r_ui=3.0, est=4.198074222985046, details={'was_impossible': False}),
#  Prediction(uid='897', iid='568', r_ui=5.0, est=3.854959780388326, details={'was_impossible': False}),
#  Prediction(uid='326', iid='493', r_ui=5.0, est=3.727947356744588, details={'was_impossible': False}),
#  Prediction(uid='77', iid='69', r_ui=3.0, est=3.7284921514591596, details={'was_impossible': False}),
#  Prediction(uid='14', iid='455', r_ui=4.0, est=3.6830394014366847, details={'was_impossible': False}),
#  Prediction(uid='236', iid='717', r_ui=3.0, est=2.391918540615142, details={'was_impossible': False}),
#  Prediction(uid='932', iid='541', r_ui=1.0, est=3.31174414923774, details={'was_impossible': False}),
#  Prediction(uid='265', iid='293', r_ui=4.0, est=3.977555149479243, details={'was_impossible': False}),
#  Prediction(uid='862', iid='845', r_ui=4.0, est=4.22989750312127, details={'was_impossible': False}),
#  Prediction(uid='819', iid='302', r_ui=5.0, est=4.631946980475036, details={'was_impossible': False}),
#  Prediction(uid='455', iid='515', r_ui=4.0, est=4.00026605195798, details={'was_impossible': False}),
#  Prediction(uid='55', iid='597', r_ui=2.0, est=2.976328510461179, details={'was_impossible': False}),
#  Prediction(uid='393', iid='1000', r_ui=3.0, est=3.556398410676181, details={'was_impossible': False}),
#  Prediction(uid='554', iid='13', r_ui=2.0, est=3.152786744721588, details={'was_impossible': False}),
#  Prediction(uid='586', iid='123', r_ui=3.0, est=3.017014591193729, details={'was_impossible': False}),
#  Prediction(uid='512', iid='191', r_ui=4.0, est=4.491955974485336, details={'was_impossible': False}),
#  Prediction(uid='535', iid='519', r_ui=3.0, est=3.9665295586953158, details={'was_impossible': False}),
#  Prediction(uid='10', iid='530', r_ui=4.0, est=4.4603915645824275, details={'was_impossible': False}),
#  Prediction(uid='535', iid='686', r_ui=5.0, est=3.846011938794842, details={'was_impossible': False}),
#  Prediction(uid='592', iid='735', r_ui=5.0, est=4.373445147228141, details={'was_impossible': False}),
#  Prediction(uid='308', iid='520', r_ui=4.0, est=3.93769869247748, details={'was_impossible': False}),
#  Prediction(uid='548', iid='597', r_ui=4.0, est=3.6844665758009656, details={'was_impossible': False}),
#  Prediction(uid='784', iid='269', r_ui=5.0, est=4.203651997255649, details={'was_impossible': False}),
#  Prediction(uid='653', iid='54', r_ui=3.0, est=2.8296468593816213, details={'was_impossible': False}),
#  Prediction(uid='707', iid='526', r_ui=1.0, est=3.801509533822997, details={'was_impossible': False}),
#  Prediction(uid='774', iid='218', r_ui=1.0, est=2.0071738273110844, details={'was_impossible': False}),
#  Prediction(uid='369', iid='271', r_ui=5.0, est=3.77608080218993, details={'was_impossible': False}),
#  Prediction(uid='771', iid='88', r_ui=4.0, est=3.605275251754659, details={'was_impossible': False}),
#  Prediction(uid='691', iid='64', r_ui=5.0, est=4.772802455128895, details={'was_impossible': False}),
#  Prediction(uid='627', iid='631', r_ui=3.0, est=3.434000965499734, details={'was_impossible': False}),
#  Prediction(uid='587', iid='334', r_ui=3.0, est=2.810042043032638, details={'was_impossible': False}),
#  Prediction(uid='316', iid='234', r_ui=1.0, est=3.0823569912051254, details={'was_impossible': False}),
#  Prediction(uid='7', iid='53', r_ui=5.0, est=3.6098131366081327, details={'was_impossible': False}),
#  Prediction(uid='234', iid='465', r_ui=2.0, est=3.2510965535389205, details={'was_impossible': False}),
#  Prediction(uid='159', iid='243', r_ui=4.0, est=3.149026701567643, details={'was_impossible': False}),
#  Prediction(uid='312', iid='156', r_ui=3.0, est=4.122461568693172, details={'was_impossible': False}),
#  Prediction(uid='757', iid='204', r_ui=4.0, est=3.7748062022960536, details={'was_impossible': False}),
#  Prediction(uid='642', iid='1058', r_ui=3.0, est=4.340176154108577, details={'was_impossible': False}),
#  Prediction(uid='197', iid='231', r_ui=3.0, est=2.1347650756311545, details={'was_impossible': False}),
#  Prediction(uid='403', iid='7', r_ui=5.0, est=3.919116813454414, details={'was_impossible': False}),
#  Prediction(uid='18', iid='519', r_ui=4.0, est=4.308935109531633, details={'was_impossible': False}),
#  Prediction(uid='457', iid='162', r_ui=5.0, est=4.088886545274502, details={'was_impossible': False}),
#  Prediction(uid='638', iid='194', r_ui=3.0, est=3.983339914283513, details={'was_impossible': False}),
#  Prediction(uid='848', iid='165', r_ui=5.0, est=4.65497556449413, details={'was_impossible': False}),
#  Prediction(uid='485', iid='319', r_ui=3.0, est=2.5988544650137144, details={'was_impossible': False}),
#  Prediction(uid='42', iid='655', r_ui=3.0, est=3.931794492755248, details={'was_impossible': False}),
#  Prediction(uid='625', iid='855', r_ui=4.0, est=3.683815390260076, details={'was_impossible': False}),
#  Prediction(uid='213', iid='288', r_ui=4.0, est=4.090505589897592, details={'was_impossible': False}),
#  Prediction(uid='276', iid='258', r_ui=5.0, est=4.054315410448391, details={'was_impossible': False}),
#  Prediction(uid='699', iid='124', r_ui=4.0, est=3.5383312952024095, details={'was_impossible': False}),
#  Prediction(uid='128', iid='1192', r_ui=2.0, est=3.472716645017499, details={'was_impossible': False}),
#  Prediction(uid='393', iid='1001', r_ui=4.0, est=2.1129877391971355, details={'was_impossible': False}),
#  Prediction(uid='463', iid='268', r_ui=4.0, est=2.433704633509568, details={'was_impossible': False}),
#  Prediction(uid='131', iid='276', r_ui=5.0, est=3.5824074649913595, details={'was_impossible': False}),
#  Prediction(uid='399', iid='148', r_ui=4.0, est=2.8598605417898098, details={'was_impossible': False}),
#  Prediction(uid='119', iid='537', r_ui=5.0, est=4.013985295892544, details={'was_impossible': False}),
#  Prediction(uid='327', iid='11', r_ui=4.0, est=3.599421024565345, details={'was_impossible': False}),
#  Prediction(uid='793', iid='240', r_ui=4.0, est=2.9115867968596008, details={'was_impossible': False}),
#  Prediction(uid='167', iid='641', r_ui=4.0, est=3.8609084837412593, details={'was_impossible': False}),
#  Prediction(uid='504', iid='56', r_ui=3.0, est=3.686821844499747, details={'was_impossible': False}),
#  Prediction(uid='425', iid='334', r_ui=4.0, est=2.8048643400030735, details={'was_impossible': False}),
#  Prediction(uid='234', iid='837', r_ui=3.0, est=3.642405731767816, details={'was_impossible': False}),
#  Prediction(uid='293', iid='416', r_ui=4.0, est=3.083467581579474, details={'was_impossible': False}),
#  Prediction(uid='532', iid='353', r_ui=2.0, est=3.1954355298179813, details={'was_impossible': False}),
#  Prediction(uid='466', iid='748', r_ui=2.0, est=3.43717044930729, details={'was_impossible': False}),
#  Prediction(uid='621', iid='1013', r_ui=2.0, est=2.345091571167479, details={'was_impossible': False}),
#  Prediction(uid='457', iid='367', r_ui=4.0, est=3.6151036890700947, details={'was_impossible': False}),
#  Prediction(uid='119', iid='1202', r_ui=4.0, est=4.092719870193231, details={'was_impossible': False}),
#  Prediction(uid='293', iid='211', r_ui=4.0, est=3.5693768102209726, details={'was_impossible': False}),
#  Prediction(uid='584', iid='109', r_ui=4.0, est=3.340305124109683, details={'was_impossible': False}),
#  Prediction(uid='693', iid='649', r_ui=2.0, est=2.9445357610579204, details={'was_impossible': False}),
#  Prediction(uid='442', iid='26', r_ui=3.0, est=3.2244268703039585, details={'was_impossible': False}),
#  Prediction(uid='894', iid='512', r_ui=5.0, est=4.194245492752706, details={'was_impossible': False}),
#  Prediction(uid='236', iid='294', r_ui=2.0, est=2.8014880640600093, details={'was_impossible': False}),
#  Prediction(uid='70', iid='109', r_ui=3.0, est=3.0731927431095816, details={'was_impossible': False}),
#  Prediction(uid='409', iid='1070', r_ui=4.0, est=3.6657043650086334, details={'was_impossible': False}),
#  Prediction(uid='749', iid='185', r_ui=4.0, est=4.102102106409679, details={'was_impossible': False}),
#  Prediction(uid='7', iid='526', r_ui=5.0, est=4.191336591866932, details={'was_impossible': False}),
#  Prediction(uid='320', iid='71', r_ui=3.0, est=3.731002271534673, details={'was_impossible': False}),
#  Prediction(uid='114', iid='210', r_ui=3.0, est=3.577727476672497, details={'was_impossible': False}),
#  Prediction(uid='144', iid='262', r_ui=3.0, est=4.046029566009869, details={'was_impossible': False}),
#  Prediction(uid='10', iid='495', r_ui=4.0, est=3.894349076896379, details={'was_impossible': False}),
#  Prediction(uid='43', iid='64', r_ui=5.0, est=4.781156020505779, details={'was_impossible': False}),
#  Prediction(uid='450', iid='222', r_ui=3.0, est=4.1677229985370925, details={'was_impossible': False}),
#  Prediction(uid='429', iid='249', r_ui=4.0, est=3.276729499204394, details={'was_impossible': False}),
#  Prediction(uid='606', iid='239', r_ui=4.0, est=4.16255460951296, details={'was_impossible': False}),
#  Prediction(uid='666', iid='11', r_ui=4.0, est=3.4891955408658695, details={'was_impossible': False}),
#  Prediction(uid='897', iid='140', r_ui=3.0, est=3.7850991358615897, details={'was_impossible': False}),
#  Prediction(uid='693', iid='289', r_ui=3.0, est=2.6577315836432236, details={'was_impossible': False}),
#  Prediction(uid='506', iid='274', r_ui=4.0, est=3.6948639018919205, details={'was_impossible': False}),
#  Prediction(uid='479', iid='205', r_ui=3.0, est=3.62521538210856, details={'was_impossible': False}),
#  Prediction(uid='221', iid='218', r_ui=4.0, est=3.509773380007052, details={'was_impossible': False}),
#  Prediction(uid='235', iid='319', r_ui=4.0, est=3.2973920964596206, details={'was_impossible': False}),
#  Prediction(uid='416', iid='159', r_ui=1.0, est=3.984856704434019, details={'was_impossible': False}),
#  Prediction(uid='590', iid='111', r_ui=3.0, est=3.1525461079928783, details={'was_impossible': False}),
#  Prediction(uid='342', iid='114', r_ui=5.0, est=4.134415964096943, details={'was_impossible': False}),
#  Prediction(uid='600', iid='1419', r_ui=3.0, est=2.66341226679187, details={'was_impossible': False}),
#  Prediction(uid='301', iid='1', r_ui=4.0, est=3.660900584271728, details={'was_impossible': False}),
#  Prediction(uid='461', iid='682', r_ui=1.0, est=2.978823126683726, details={'was_impossible': False}),
#  Prediction(uid='149', iid='340', r_ui=4.0, est=3.270360923618172, details={'was_impossible': False}),
#  Prediction(uid='890', iid='521', r_ui=5.0, est=4.05966052501204, details={'was_impossible': False}),
#  Prediction(uid='722', iid='7', r_ui=4.0, est=3.9192766001598076, details={'was_impossible': False}),
#  Prediction(uid='664', iid='47', r_ui=4.0, est=3.769086555226879, details={'was_impossible': False}),
#  Prediction(uid='645', iid='211', r_ui=4.0, est=4.282383388142281, details={'was_impossible': False}),
#  Prediction(uid='805', iid='934', r_ui=1.0, est=2.8829339305272073, details={'was_impossible': False}),
#  Prediction(uid='53', iid='15', r_ui=5.0, est=4.085436318668529, details={'was_impossible': False}),
#  Prediction(uid='554', iid='265', r_ui=4.0, est=3.8612905399768, details={'was_impossible': False}),
#  Prediction(uid='130', iid='331', r_ui=3.0, est=4.050968489471489, details={'was_impossible': False}),
#  Prediction(uid='13', iid='87', r_ui=5.0, est=3.2122520976542113, details={'was_impossible': False}),
#  Prediction(uid='105', iid='324', r_ui=4.0, est=3.2141048997335386, details={'was_impossible': False}),
#  Prediction(uid='286', iid='235', r_ui=4.0, est=3.665861054683364, details={'was_impossible': False}),
#  Prediction(uid='497', iid='423', r_ui=3.0, est=3.4574077681068927, details={'was_impossible': False}),
#  Prediction(uid='407', iid='202', r_ui=4.0, est=3.5186430709687175, details={'was_impossible': False}),
#  Prediction(uid='561', iid='393', r_ui=2.0, est=2.0613434688255126, details={'was_impossible': False}),
#  Prediction(uid='679', iid='527', r_ui=4.0, est=3.547363327312796, details={'was_impossible': False}),
#  Prediction(uid='559', iid='261', r_ui=3.0, est=2.445516958416531, details={'was_impossible': False}),
#  Prediction(uid='566', iid='742', r_ui=3.0, est=3.3113695356123465, details={'was_impossible': False}),
#  Prediction(uid='2', iid='25', r_ui=4.0, est=3.632884682988572, details={'was_impossible': False}),
#  Prediction(uid='744', iid='482', r_ui=3.0, est=4.087336265365964, details={'was_impossible': False}),
#  Prediction(uid='268', iid='370', r_ui=2.0, est=2.3505281424465188, details={'was_impossible': False}),
#  Prediction(uid='697', iid='235', r_ui=4.0, est=3.0065449108460274, details={'was_impossible': False}),
#  Prediction(uid='747', iid='70', r_ui=4.0, est=3.8876804239507106, details={'was_impossible': False}),
#  Prediction(uid='870', iid='127', r_ui=5.0, est=4.23964965972663, details={'was_impossible': False}),
#  Prediction(uid='481', iid='210', r_ui=4.0, est=3.887687420517878, details={'was_impossible': False}),
#  Prediction(uid='710', iid='357', r_ui=4.0, est=4.217732942628796, details={'was_impossible': False}),
#  Prediction(uid='606', iid='841', r_ui=3.0, est=3.120822681206718, details={'was_impossible': False}),
#  Prediction(uid='365', iid='815', r_ui=3.0, est=3.230772347655176, details={'was_impossible': False}),
#  Prediction(uid='567', iid='483', r_ui=5.0, est=4.553721331944346, details={'was_impossible': False}),
#  Prediction(uid='276', iid='1081', r_ui=3.0, est=3.6312249328339443, details={'was_impossible': False}),
#  Prediction(uid='96', iid='83', r_ui=3.0, est=4.303740967870454, details={'was_impossible': False}),
#  Prediction(uid='389', iid='173', r_ui=3.0, est=4.0940535990995315, details={'was_impossible': False}),
#  Prediction(uid='682', iid='1188', r_ui=3.0, est=2.656087496870654, details={'was_impossible': False}),
#  Prediction(uid='275', iid='162', r_ui=3.0, est=3.1230429811497555, details={'was_impossible': False}),
#  Prediction(uid='184', iid='276', r_ui=4.0, est=4.078868260506063, details={'was_impossible': False}),
#  Prediction(uid='886', iid='693', r_ui=4.0, est=3.4213105814987785, details={'was_impossible': False}),
#  Prediction(uid='307', iid='154', r_ui=5.0, est=3.980742839362472, details={'was_impossible': False}),
#  Prediction(uid='595', iid='1009', r_ui=4.0, est=3.5615510285947116, details={'was_impossible': False}),
#  Prediction(uid='715', iid='118', r_ui=2.0, est=2.9322316000821584, details={'was_impossible': False}),
#  Prediction(uid='494', iid='9', r_ui=2.0, est=4.169794172282081, details={'was_impossible': False}),
#  Prediction(uid='654', iid='87', r_ui=4.0, est=3.8325437282985972, details={'was_impossible': False}),
#  Prediction(uid='774', iid='732', r_ui=1.0, est=2.4446515687944292, details={'was_impossible': False}),
#  Prediction(uid='653', iid='763', r_ui=1.0, est=3.2781300409780223, details={'was_impossible': False}),
#  Prediction(uid='222', iid='627', r_ui=3.0, est=3.0778279210644777, details={'was_impossible': False}),
#  Prediction(uid='487', iid='50', r_ui=4.0, est=4.2695223671516045, details={'was_impossible': False}),
#  Prediction(uid='7', iid='201', r_ui=2.0, est=4.166772694928678, details={'was_impossible': False}),
#  Prediction(uid='533', iid='596', r_ui=2.0, est=3.0580823952422413, details={'was_impossible': False}),
#  Prediction(uid='605', iid='483', r_ui=5.0, est=4.525947220346943, details={'was_impossible': False}),
#  Prediction(uid='730', iid='117', r_ui=3.0, est=3.6559551005413797, details={'was_impossible': False}),
#  Prediction(uid='505', iid='176', r_ui=4.0, est=3.2841452675519185, details={'was_impossible': False}),
#  Prediction(uid='919', iid='477', r_ui=4.0, est=3.0367867479083466, details={'was_impossible': False}),
#  Prediction(uid='294', iid='288', r_ui=5.0, est=3.910044927719995, details={'was_impossible': False}),
#  Prediction(uid='21', iid='444', r_ui=3.0, est=2.604755306143108, details={'was_impossible': False}),
#  Prediction(uid='745', iid='646', r_ui=4.0, est=3.282842629362626, details={'was_impossible': False}),
#  Prediction(uid='847', iid='238', r_ui=2.0, est=3.0929112097326223, details={'was_impossible': False}),
#  Prediction(uid='890', iid='451', r_ui=2.0, est=3.5308024792912285, details={'was_impossible': False}),
#  Prediction(uid='749', iid='633', r_ui=4.0, est=3.8730615762032654, details={'was_impossible': False}),
#  Prediction(uid='833', iid='235', r_ui=4.0, est=2.0058212084225366, details={'was_impossible': False}),
#  Prediction(uid='176', iid='297', r_ui=3.0, est=4.2064355254795265, details={'was_impossible': False}),
#  Prediction(uid='892', iid='133', r_ui=3.0, est=4.0994395917421445, details={'was_impossible': False}),
#  Prediction(uid='615', iid='666', r_ui=2.0, est=3.468132457343298, details={'was_impossible': False}),
#  Prediction(uid='796', iid='78', r_ui=3.0, est=2.4780573029738053, details={'was_impossible': False}),
#  Prediction(uid='190', iid='281', r_ui=3.0, est=3.1548984113077876, details={'was_impossible': False}),
#  Prediction(uid='867', iid='210', r_ui=5.0, est=4.502989041272539, details={'was_impossible': False}),
#  Prediction(uid='553', iid='178', r_ui=5.0, est=4.642558459821125, details={'was_impossible': False}),
#  Prediction(uid='804', iid='1411', r_ui=3.0, est=3.0555910672081352, details={'was_impossible': False}),
#  Prediction(uid='89', iid='127', r_ui=5.0, est=4.659865903343308, details={'was_impossible': False}),
#  Prediction(uid='931', iid='312', r_ui=4.0, est=2.8236142519456227, details={'was_impossible': False}),
#  Prediction(uid='378', iid='117', r_ui=3.0, est=3.4096703275328304, details={'was_impossible': False}),
#  Prediction(uid='224', iid='286', r_ui=3.0, est=2.797604885358709, details={'was_impossible': False}),
#  Prediction(uid='582', iid='932', r_ui=2.0, est=3.0658444723112637, details={'was_impossible': False}),
#  Prediction(uid='91', iid='211', r_ui=2.0, est=3.4352705085307473, details={'was_impossible': False}),
#  Prediction(uid='494', iid='329', r_ui=3.0, est=3.014959881208124, details={'was_impossible': False}),
#  Prediction(uid='165', iid='156', r_ui=3.0, est=4.165400397066124, details={'was_impossible': False}),
#  Prediction(uid='635', iid='333', r_ui=5.0, est=3.2263099138871967, details={'was_impossible': False}),
#  Prediction(uid='354', iid='305', r_ui=4.0, est=3.564004350747874, details={'was_impossible': False}),
#  Prediction(uid='889', iid='386', r_ui=3.0, est=2.3879802699261155, details={'was_impossible': False}),
#  Prediction(uid='802', iid='286', r_ui=2.0, est=3.477303594817954, details={'was_impossible': False}),
#  Prediction(uid='276', iid='148', r_ui=3.0, est=3.0102720201257376, details={'was_impossible': False}),
#  Prediction(uid='773', iid='567', r_ui=2.0, est=2.5255551127806966, details={'was_impossible': False}),
#  Prediction(uid='839', iid='106', r_ui=2.0, est=2.7271160660818676, details={'was_impossible': False}),
#  Prediction(uid='601', iid='416', r_ui=3.0, est=3.086096459808883, details={'was_impossible': False}),
#  Prediction(uid='75', iid='240', r_ui=1.0, est=3.909106875299619, details={'was_impossible': False}),
#  Prediction(uid='399', iid='470', r_ui=4.0, est=3.3412069808867346, details={'was_impossible': False}),
#  Prediction(uid='16', iid='705', r_ui=5.0, est=4.553701893544742, details={'was_impossible': False}),
#  Prediction(uid='405', iid='1478', r_ui=1.0, est=1.9490827028722624, details={'was_impossible': False}),
#  Prediction(uid='653', iid='696', r_ui=1.0, est=2.758792107536629, details={'was_impossible': False}),
#  Prediction(uid='768', iid='248', r_ui=3.0, est=3.2046410703966397, details={'was_impossible': False}),
#  Prediction(uid='660', iid='230', r_ui=3.0, est=2.5138173855069974, details={'was_impossible': False}),
#  Prediction(uid='847', iid='1137', r_ui=5.0, est=3.476007115820107, details={'was_impossible': False}),
#  Prediction(uid='85', iid='1103', r_ui=3.0, est=3.845959204088708, details={'was_impossible': False}),
#  Prediction(uid='347', iid='87', r_ui=3.0, est=3.798235437101199, details={'was_impossible': False}),
#  Prediction(uid='450', iid='144', r_ui=5.0, est=3.7891276009523085, details={'was_impossible': False}),
#  Prediction(uid='107', iid='302', r_ui=4.0, est=3.845964163551789, details={'was_impossible': False}),
#  Prediction(uid='521', iid='679', r_ui=3.0, est=2.6236159936934076, details={'was_impossible': False}),
#  Prediction(uid='74', iid='331', r_ui=4.0, est=3.5543580007279854, details={'was_impossible': False}),
#  Prediction(uid='567', iid='612', r_ui=4.0, est=3.516489025546742, details={'was_impossible': False}),
#  Prediction(uid='79', iid='236', r_ui=5.0, est=3.4658416501653573, details={'was_impossible': False}),
#  Prediction(uid='280', iid='323', r_ui=2.0, est=3.161121544653319, details={'was_impossible': False}),
#  Prediction(uid='271', iid='4', r_ui=5.0, est=3.7339835875913923, details={'was_impossible': False}),
#  Prediction(uid='896', iid='1222', r_ui=2.0, est=2.4516552032461005, details={'was_impossible': False}),
#  Prediction(uid='13', iid='782', r_ui=3.0, est=3.230273801791235, details={'was_impossible': False}),
#  Prediction(uid='788', iid='76', r_ui=3.0, est=3.3945192828061304, details={'was_impossible': False}),
#  Prediction(uid='343', iid='76', r_ui=4.0, est=3.708588625429052, details={'was_impossible': False}),
#  Prediction(uid='768', iid='756', r_ui=3.0, est=2.442580750204425, details={'was_impossible': False}),
#  Prediction(uid='707', iid='1176', r_ui=2.0, est=3.5975087422318612, details={'was_impossible': False}),
#  Prediction(uid='653', iid='1267', r_ui=1.0, est=2.381015204919466, details={'was_impossible': False}),
#  Prediction(uid='655', iid='326', r_ui=2.0, est=2.808736985584408, details={'was_impossible': False}),
#  Prediction(uid='297', iid='625', r_ui=3.0, est=3.106509788461968, details={'was_impossible': False}),
#  Prediction(uid='491', iid='19', r_ui=4.0, est=4.0053231584927005, details={'was_impossible': False}),
#  Prediction(uid='899', iid='214', r_ui=4.0, est=3.332095198090658, details={'was_impossible': False}),
#  Prediction(uid='203', iid='237', r_ui=3.0, est=3.6593079014025425, details={'was_impossible': False}),
#  Prediction(uid='702', iid='350', r_ui=1.0, est=2.673763875565848, details={'was_impossible': False}),
#  Prediction(uid='825', iid='1008', r_ui=1.0, est=3.91046381198415, details={'was_impossible': False}),
#  Prediction(uid='634', iid='985', r_ui=4.0, est=3.2261516600968587, details={'was_impossible': False}),
#  Prediction(uid='318', iid='132', r_ui=4.0, est=4.286815045666323, details={'was_impossible': False}),
#  Prediction(uid='276', iid='1482', r_ui=4.0, est=3.506426488768058, details={'was_impossible': False}),
#  Prediction(uid='59', iid='51', r_ui=5.0, est=3.9178214040043287, details={'was_impossible': False}),
#  Prediction(uid='763', iid='26', r_ui=4.0, est=3.266955859345725, details={'was_impossible': False}),
#  Prediction(uid='663', iid='260', r_ui=2.0, est=2.7112088938810137, details={'was_impossible': False}),
#  Prediction(uid='889', iid='159', r_ui=3.0, est=3.1745708897585354, details={'was_impossible': False}),
#  Prediction(uid='32', iid='271', r_ui=3.0, est=3.2307649993140295, details={'was_impossible': False}),
#  Prediction(uid='416', iid='241', r_ui=5.0, est=3.8541755907405726, details={'was_impossible': False}),
#  Prediction(uid='201', iid='144', r_ui=4.0, est=3.6735727423770923, details={'was_impossible': False}),
#  Prediction(uid='896', iid='11', r_ui=2.0, est=3.5220202133043803, details={'was_impossible': False}),
#  Prediction(uid='727', iid='118', r_ui=4.0, est=2.6541015267829313, details={'was_impossible': False}),
#  Prediction(uid='263', iid='333', r_ui=2.0, est=3.7745247532978485, details={'was_impossible': False}),
#  Prediction(uid='771', iid='313', r_ui=3.0, est=4.4325984623545605, details={'was_impossible': False}),
#  Prediction(uid='92', iid='674', r_ui=4.0, est=3.1243246147218264, details={'was_impossible': False}),
#  Prediction(uid='622', iid='106', r_ui=2.0, est=2.895755994718729, details={'was_impossible': False}),
#  Prediction(uid='484', iid='22', r_ui=5.0, est=4.599376432024865, details={'was_impossible': False}),
#  Prediction(uid='912', iid='132', r_ui=5.0, est=3.8152641067460618, details={'was_impossible': False}),
#  Prediction(uid='308', iid='404', r_ui=3.0, est=3.569770510549907, details={'was_impossible': False}),
#  Prediction(uid='865', iid='847', r_ui=5.0, est=2.6870176610033893, details={'was_impossible': False}),
#  Prediction(uid='94', iid='219', r_ui=4.0, est=3.383122349891449, details={'was_impossible': False}),
#  Prediction(uid='286', iid='559', r_ui=4.0, est=3.837898889748446, details={'was_impossible': False}),
#  Prediction(uid='499', iid='271', r_ui=3.0, est=3.287891730470896, details={'was_impossible': False}),
#  Prediction(uid='161', iid='69', r_ui=4.0, est=2.375294587139493, details={'was_impossible': False}),
#  Prediction(uid='682', iid='157', r_ui=4.0, est=3.408317646955357, details={'was_impossible': False}),
#  Prediction(uid='537', iid='318', r_ui=4.0, est=3.91892841174118, details={'was_impossible': False}),
#  Prediction(uid='903', iid='628', r_ui=3.0, est=3.6014518223529604, details={'was_impossible': False}),
#  Prediction(uid='130', iid='316', r_ui=4.0, est=4.8327277104432245, details={'was_impossible': False}),
#  Prediction(uid='269', iid='13', r_ui=4.0, est=2.724141762542487, details={'was_impossible': False}),
#  Prediction(uid='188', iid='684', r_ui=3.0, est=4.0680690444649015, details={'was_impossible': False}),
#  Prediction(uid='721', iid='948', r_ui=1.0, est=2.798393759756933, details={'was_impossible': False}),
#  Prediction(uid='59', iid='659', r_ui=3.0, est=4.620963383372498, details={'was_impossible': False}),
#  Prediction(uid='253', iid='12', r_ui=5.0, est=4.676987012801998, details={'was_impossible': False}),
#  Prediction(uid='324', iid='270', r_ui=5.0, est=4.493554271702181, details={'was_impossible': False}),
#  Prediction(uid='239', iid='10', r_ui=5.0, est=4.172859811935888, details={'was_impossible': False}),
#  Prediction(uid='97', iid='32', r_ui=5.0, est=3.9169304956301763, details={'was_impossible': False}),
#  Prediction(uid='798', iid='405', r_ui=5.0, est=3.7339525486122147, details={'was_impossible': False}),
#  Prediction(uid='833', iid='919', r_ui=2.0, est=3.308064235043747, details={'was_impossible': False}),
#  Prediction(uid='521', iid='132', r_ui=3.0, est=3.4589424887236495, details={'was_impossible': False}),
#  Prediction(uid='1', iid='87', r_ui=5.0, est=3.832535159146133, details={'was_impossible': False}),
#  Prediction(uid='344', iid='280', r_ui=3.0, est=3.183453060316254, details={'was_impossible': False}),
#  Prediction(uid='405', iid='11', r_ui=4.0, est=2.6272336430948053, details={'was_impossible': False}),
#  Prediction(uid='393', iid='363', r_ui=3.0, est=2.828651190819207, details={'was_impossible': False}),
#  Prediction(uid='399', iid='559', r_ui=3.0, est=2.5032517752478163, details={'was_impossible': False}),
#  Prediction(uid='501', iid='100', r_ui=4.0, est=4.197225667681046, details={'was_impossible': False}),
#  Prediction(uid='142', iid='322', r_ui=2.0, est=3.1329131980179157, details={'was_impossible': False}),
#  Prediction(uid='489', iid='325', r_ui=5.0, est=3.3243955222116335, details={'was_impossible': False}),
#  Prediction(uid='819', iid='315', r_ui=5.0, est=4.2401811331230705, details={'was_impossible': False}),
#  Prediction(uid='472', iid='200', r_ui=4.0, est=4.478274448370603, details={'was_impossible': False}),
#  Prediction(uid='437', iid='216', r_ui=5.0, est=3.8400650099550617, details={'was_impossible': False}),
#  Prediction(uid='943', iid='475', r_ui=5.0, est=3.8959328903328876, details={'was_impossible': False}),
#  Prediction(uid='314', iid='722', r_ui=1.0, est=3.8312594915047145, details={'was_impossible': False}),
#  Prediction(uid='605', iid='260', r_ui=4.0, est=2.4923552386720678, details={'was_impossible': False}),
#  Prediction(uid='459', iid='825', r_ui=3.0, est=3.118649289504811, details={'was_impossible': False}),
#  Prediction(uid='494', iid='15', r_ui=5.0, est=3.905472853006945, details={'was_impossible': False}),
#  Prediction(uid='425', iid='259', r_ui=1.0, est=2.225951404162056, details={'was_impossible': False}),
#  Prediction(uid='592', iid='328', r_ui=1.0, est=2.666266030915186, details={'was_impossible': False}),
#  Prediction(uid='935', iid='120', r_ui=3.0, est=2.9376298358898216, details={'was_impossible': False}),
#  Prediction(uid='823', iid='91', r_ui=3.0, est=4.012852610560407, details={'was_impossible': False}),
#  Prediction(uid='721', iid='359', r_ui=3.0, est=3.991916048626703, details={'was_impossible': False}),
#  Prediction(uid='279', iid='12', r_ui=2.0, est=4.099758460466218, details={'was_impossible': False}),
#  Prediction(uid='253', iid='331', r_ui=3.0, est=3.6436706350596144, details={'was_impossible': False}),
#  Prediction(uid='151', iid='195', r_ui=3.0, est=3.9495511942177264, details={'was_impossible': False}),
#  Prediction(uid='107', iid='333', r_ui=3.0, est=2.9852204052360003, details={'was_impossible': False}),
#  Prediction(uid='755', iid='872', r_ui=1.0, est=3.1844912546450903, details={'was_impossible': False}),
#  Prediction(uid='72', iid='5', r_ui=4.0, est=3.1667984214662113, details={'was_impossible': False}),
#  Prediction(uid='891', iid='459', r_ui=5.0, est=4.272730582269094, details={'was_impossible': False}),
#  Prediction(uid='314', iid='377', r_ui=3.0, est=3.0157039950125037, details={'was_impossible': False}),
#  Prediction(uid='782', iid='286', r_ui=2.0, est=2.8034260862592246, details={'was_impossible': False}),
#  Prediction(uid='741', iid='265', r_ui=5.0, est=3.7209972813603276, details={'was_impossible': False}),
#  Prediction(uid='896', iid='631', r_ui=2.0, est=3.1093949437648396, details={'was_impossible': False}),
#  Prediction(uid='627', iid='282', r_ui=2.0, est=3.6936351770003206, details={'was_impossible': False}),
#  Prediction(uid='880', iid='254', r_ui=2.0, est=2.520097794780978, details={'was_impossible': False}),
#  Prediction(uid='727', iid='92', r_ui=2.0, est=3.3386112187850996, details={'was_impossible': False}),
#  Prediction(uid='303', iid='808', r_ui=2.0, est=2.784733595600758, details={'was_impossible': False}),
#  Prediction(uid='618', iid='356', r_ui=2.0, est=3.498735150347363, details={'was_impossible': False}),
#  Prediction(uid='276', iid='198', r_ui=5.0, est=3.862406432131198, details={'was_impossible': False}),
#  Prediction(uid='318', iid='941', r_ui=4.0, est=3.269931980142574, details={'was_impossible': False}),
#  Prediction(uid='927', iid='91', r_ui=4.0, est=3.916620422343628, details={'was_impossible': False}),
#  Prediction(uid='114', iid='269', r_ui=4.0, est=3.3923974281129334, details={'was_impossible': False}),
#  Prediction(uid='715', iid='976', r_ui=1.0, est=2.6742052596452095, details={'was_impossible': False}),
#  Prediction(uid='907', iid='1057', r_ui=3.0, est=3.7448758704679435, details={'was_impossible': False}),
#  Prediction(uid='847', iid='367', r_ui=3.0, est=2.8362368129805633, details={'was_impossible': False}),
#  Prediction(uid='7', iid='480', r_ui=4.0, est=4.577066217214145, details={'was_impossible': False}),
#  Prediction(uid='620', iid='595', r_ui=5.0, est=3.529094229785498, details={'was_impossible': False}),
#  Prediction(uid='166', iid='894', r_ui=4.0, est=2.6875071643036397, details={'was_impossible': False}),
#  Prediction(uid='7', iid='234', r_ui=5.0, est=4.270264339129343, details={'was_impossible': False}),
#  Prediction(uid='878', iid='1149', r_ui=4.0, est=3.304483358709369, details={'was_impossible': False}),
#  Prediction(uid='655', iid='86', r_ui=4.0, est=3.419209329591112, details={'was_impossible': False}),
#  Prediction(uid='524', iid='203', r_ui=4.0, est=3.8050636331036953, details={'was_impossible': False}),
#  Prediction(uid='59', iid='367', r_ui=4.0, est=3.878743383126919, details={'was_impossible': False}),
#  Prediction(uid='313', iid='673', r_ui=4.0, est=3.619275581181372, details={'was_impossible': False}),
#  Prediction(uid='239', iid='1115', r_ui=2.0, est=3.728758040625192, details={'was_impossible': False}),
#  Prediction(uid='468', iid='173', r_ui=5.0, est=4.493541787831591, details={'was_impossible': False}),
#  Prediction(uid='790', iid='213', r_ui=3.0, est=3.4446039508759325, details={'was_impossible': False}),
#  Prediction(uid='887', iid='168', r_ui=4.0, est=4.2652140153909714, details={'was_impossible': False}),
#  Prediction(uid='588', iid='842', r_ui=3.0, est=3.529743648727399, details={'was_impossible': False}),
#  Prediction(uid='213', iid='447', r_ui=4.0, est=4.158264476227208, details={'was_impossible': False}),
#  Prediction(uid='198', iid='1117', r_ui=3.0, est=2.7894763074309923, details={'was_impossible': False}),
#  Prediction(uid='13', iid='68', r_ui=3.0, est=3.1460047140103127, details={'was_impossible': False}),
#  Prediction(uid='450', iid='710', r_ui=3.0, est=3.9969827916590472, details={'was_impossible': False}),
#  Prediction(uid='416', iid='790', r_ui=4.0, est=3.4723546089985184, details={'was_impossible': False}),
#  Prediction(uid='894', iid='315', r_ui=4.0, est=4.398450312215852, details={'was_impossible': False}),
#  Prediction(uid='16', iid='33', r_ui=2.0, est=4.2463824157397685, details={'was_impossible': False}),
#  Prediction(uid='233', iid='133', r_ui=5.0, est=4.132716173453661, details={'was_impossible': False}),
#  Prediction(uid='200', iid='226', r_ui=4.0, est=4.32517536771253, details={'was_impossible': False}),
#  Prediction(uid='515', iid='243', r_ui=3.0, est=2.2096588232147516, details={'was_impossible': False}),
#  Prediction(uid='663', iid='332', r_ui=4.0, est=3.4103595251301924, details={'was_impossible': False}),
#  Prediction(uid='551', iid='780', r_ui=5.0, est=3.25046633378336, details={'was_impossible': False}),
#  Prediction(uid='92', iid='72', r_ui=3.0, est=2.7694507617484185, details={'was_impossible': False}),
#  Prediction(uid='125', iid='1000', r_ui=3.0, est=3.213540282824922, details={'was_impossible': False}),
#  Prediction(uid='450', iid='528', r_ui=5.0, est=4.651572224780137, details={'was_impossible': False}),
#  Prediction(uid='452', iid='71', r_ui=3.0, est=3.7356117937591096, details={'was_impossible': False}),
#  Prediction(uid='395', iid='231', r_ui=4.0, est=2.899718606148894, details={'was_impossible': False}),
#  Prediction(uid='724', iid='751', r_ui=2.0, est=2.69599107489368, details={'was_impossible': False}),
#  Prediction(uid='730', iid='125', r_ui=4.0, est=3.2415870279915278, details={'was_impossible': False}),
#  Prediction(uid='66', iid='535', r_ui=4.0, est=3.17806591930297, details={'was_impossible': False}),
#  Prediction(uid='178', iid='511', r_ui=5.0, est=4.263235151284224, details={'was_impossible': False}),
#  Prediction(uid='500', iid='217', r_ui=4.0, est=3.0914999948237236, details={'was_impossible': False}),
#  Prediction(uid='346', iid='188', r_ui=4.0, est=3.7106212466533477, details={'was_impossible': False}),
#  Prediction(uid='214', iid='482', r_ui=4.0, est=4.274587747055922, details={'was_impossible': False}),
#  Prediction(uid='796', iid='315', r_ui=5.0, est=4.145394792948032, details={'was_impossible': False}),
#  Prediction(uid='766', iid='127', r_ui=5.0, est=3.9478352061084987, details={'was_impossible': False}),
#  Prediction(uid='823', iid='659', r_ui=4.0, est=4.3350039571632974, details={'was_impossible': False}),
#  Prediction(uid='861', iid='462', r_ui=4.0, est=4.04230997990851, details={'was_impossible': False}),
#  Prediction(uid='297', iid='705', r_ui=2.0, est=3.905063208453858, details={'was_impossible': False}),
#  Prediction(uid='664', iid='318', r_ui=5.0, est=4.222977033235342, details={'was_impossible': False}),
#  Prediction(uid='560', iid='258', r_ui=5.0, est=3.6128664715470697, details={'was_impossible': False}),
#  Prediction(uid='398', iid='231', r_ui=2.0, est=2.858484019217763, details={'was_impossible': False}),
#  Prediction(uid='457', iid='168', r_ui=5.0, est=4.632125391585068, details={'was_impossible': False}),
#  Prediction(uid='503', iid='14', r_ui=3.0, est=4.212845619744126, details={'was_impossible': False}),
#  Prediction(uid='472', iid='210', r_ui=5.0, est=5, details={'was_impossible': False}),
# ...
#  Prediction(uid='234', iid='30', r_ui=4.0, est=3.2574836007253536, details={'was_impossible': False}),
#  Prediction(uid='65', iid='125', r_ui=4.0, est=3.9517365817280568, details={'was_impossible': False}),
#  Prediction(uid='293', iid='161', r_ui=2.0, est=2.5459885170610397, details={'was_impossible': False}),
#  Prediction(uid='128', iid='64', r_ui=5.0, est=4.571515373418285, details={'was_impossible': False}),
#  Prediction(uid='339', iid='663', r_ui=5.0, est=4.155954816287652, details={'was_impossible': False}),
#  Prediction(uid='144', iid='303', r_ui=4.0, est=3.6959880153803466, details={'was_impossible': False}),
#  Prediction(uid='63', iid='222', r_ui=3.0, est=3.156324749986827, details={'was_impossible': False}),
#  Prediction(uid='614', iid='1009', r_ui=3.0, est=3.2180873107635986, details={'was_impossible': False}),
#  Prediction(uid='157', iid='50', r_ui=4.0, est=4.465697666047393, details={'was_impossible': False}),
#  Prediction(uid='102', iid='559', r_ui=3.0, est=2.3628300810143363, details={'was_impossible': False}),
#  Prediction(uid='552', iid='7', r_ui=3.0, est=3.7090446578107663, details={'was_impossible': False}),
#  Prediction(uid='416', iid='941', r_ui=3.0, est=3.788845745944925, details={'was_impossible': False}),
#  Prediction(uid='509', iid='289', r_ui=2.0, est=2.5173347950772675, details={'was_impossible': False}),
#  Prediction(uid='303', iid='715', r_ui=4.0, est=3.443652297761345, details={'was_impossible': False}),
#  Prediction(uid='125', iid='1272', r_ui=1.0, est=2.8563487417954847, details={'was_impossible': False}),
#  Prediction(uid='378', iid='58', r_ui=4.0, est=3.77007057042595, details={'was_impossible': False}),
#  Prediction(uid='313', iid='404', r_ui=4.0, est=3.7734288345545757, details={'was_impossible': False}),
#  Prediction(uid='393', iid='1206', r_ui=3.0, est=3.0835637571769072, details={'was_impossible': False}),
#  Prediction(uid='276', iid='564', r_ui=3.0, est=2.335095980459962, details={'was_impossible': False}),
#  Prediction(uid='854', iid='132', r_ui=5.0, est=3.6546969946742944, details={'was_impossible': False}),
#  Prediction(uid='764', iid='939', r_ui=4.0, est=3.6518121609041296, details={'was_impossible': False}),
#  Prediction(uid='193', iid='194', r_ui=4.0, est=3.840823641906869, details={'was_impossible': False}),
#  Prediction(uid='174', iid='1041', r_ui=5.0, est=3.2269974504702277, details={'was_impossible': False}),
#  Prediction(uid='157', iid='258', r_ui=3.0, est=4.322099238827598, details={'was_impossible': False}),
#  Prediction(uid='469', iid='495', r_ui=5.0, est=4.1158062535191435, details={'was_impossible': False}),
#  Prediction(uid='764', iid='405', r_ui=4.0, est=3.5167666311510994, details={'was_impossible': False}),
#  Prediction(uid='243', iid='7', r_ui=3.0, est=3.764430957699092, details={'was_impossible': False}),
#  Prediction(uid='363', iid='316', r_ui=3.0, est=3.4714189200886216, details={'was_impossible': False}),
#  Prediction(uid='705', iid='257', r_ui=4.0, est=4.173047220550183, details={'was_impossible': False}),
#  Prediction(uid='347', iid='237', r_ui=4.0, est=4.012027395487143, details={'was_impossible': False}),
#  Prediction(uid='423', iid='258', r_ui=5.0, est=4.14635010169473, details={'was_impossible': False}),
#  Prediction(uid='716', iid='393', r_ui=3.0, est=3.63169605615135, details={'was_impossible': False}),
#  Prediction(uid='296', iid='948', r_ui=1.0, est=2.712665491789114, details={'was_impossible': False}),
#  Prediction(uid='871', iid='22', r_ui=5.0, est=4.328300887112088, details={'was_impossible': False}),
#  Prediction(uid='431', iid='538', r_ui=4.0, est=3.299793651556138, details={'was_impossible': False}),
#  Prediction(uid='280', iid='566', r_ui=4.0, est=3.459077864591114, details={'was_impossible': False}),
#  Prediction(uid='354', iid='319', r_ui=3.0, est=2.8884537314212566, details={'was_impossible': False}),
#  Prediction(uid='178', iid='978', r_ui=2.0, est=2.8078795146892346, details={'was_impossible': False}),
#  Prediction(uid='870', iid='517', r_ui=2.0, est=3.5222649073098786, details={'was_impossible': False}),
#  Prediction(uid='56', iid='71', r_ui=4.0, est=4.060602036106739, details={'was_impossible': False}),
#  Prediction(uid='13', iid='40', r_ui=2.0, est=2.9036244805231384, details={'was_impossible': False}),
#  Prediction(uid='13', iid='835', r_ui=3.0, est=3.531114922877492, details={'was_impossible': False}),
#  Prediction(uid='390', iid='328', r_ui=4.0, est=3.353126131490468, details={'was_impossible': False}),
#  Prediction(uid='537', iid='216', r_ui=3.0, est=2.6238272868790133, details={'was_impossible': False}),
#  Prediction(uid='406', iid='240', r_ui=4.0, est=2.912148785238898, details={'was_impossible': False}),
#  Prediction(uid='864', iid='789', r_ui=4.0, est=3.7281796821743884, details={'was_impossible': False}),
#  Prediction(uid='279', iid='1240', r_ui=1.0, est=3.682511199647867, details={'was_impossible': False}),
#  Prediction(uid='463', iid='1017', r_ui=2.0, est=2.8225167909095368, details={'was_impossible': False}),
#  Prediction(uid='87', iid='1187', r_ui=2.0, est=4.051458605682899, details={'was_impossible': False}),
#  Prediction(uid='407', iid='675', r_ui=3.0, est=3.2009783081159093, details={'was_impossible': False}),
#  Prediction(uid='921', iid='275', r_ui=1.0, est=3.8960413222002193, details={'was_impossible': False}),
#  Prediction(uid='145', iid='393', r_ui=5.0, est=3.1950867765963715, details={'was_impossible': False}),
#  Prediction(uid='863', iid='347', r_ui=2.0, est=3.260773277487399, details={'was_impossible': False}),
#  Prediction(uid='361', iid='49', r_ui=3.0, est=3.278026707991431, details={'was_impossible': False}),
#  Prediction(uid='429', iid='128', r_ui=3.0, est=3.332799270428357, details={'was_impossible': False}),
#  Prediction(uid='611', iid='342', r_ui=3.0, est=3.394151832853105, details={'was_impossible': False}),
#  Prediction(uid='361', iid='692', r_ui=4.0, est=3.4048080813140262, details={'was_impossible': False}),
#  Prediction(uid='622', iid='737', r_ui=5.0, est=3.0226137962331348, details={'was_impossible': False}),
#  Prediction(uid='151', iid='427', r_ui=5.0, est=4.364547803814099, details={'was_impossible': False}),
#  Prediction(uid='705', iid='82', r_ui=5.0, est=3.7911232264501793, details={'was_impossible': False}),
#  Prediction(uid='653', iid='234', r_ui=3.0, est=2.7175903165290345, details={'was_impossible': False}),
#  Prediction(uid='458', iid='475', r_ui=4.0, est=3.6394477000220213, details={'was_impossible': False}),
#  Prediction(uid='328', iid='1041', r_ui=3.0, est=3.0696504561177256, details={'was_impossible': False}),
#  Prediction(uid='507', iid='345', r_ui=5.0, est=4.588653529294178, details={'was_impossible': False}),
#  Prediction(uid='333', iid='269', r_ui=2.0, est=4.136688611719553, details={'was_impossible': False}),
#  Prediction(uid='725', iid='111', r_ui=3.0, est=3.6219714597374404, details={'was_impossible': False}),
#  Prediction(uid='56', iid='748', r_ui=4.0, est=3.962830194270934, details={'was_impossible': False}),
#  Prediction(uid='250', iid='993', r_ui=5.0, est=4.021582041930477, details={'was_impossible': False}),
#  Prediction(uid='622', iid='1407', r_ui=1.0, est=2.6280016997091105, details={'was_impossible': False}),
#  Prediction(uid='308', iid='494', r_ui=5.0, est=4.094633642406907, details={'was_impossible': False}),
#  Prediction(uid='832', iid='748', r_ui=3.0, est=3.0824667773168937, details={'was_impossible': False}),
#  Prediction(uid='313', iid='892', r_ui=4.0, est=2.608611165678169, details={'was_impossible': False}),
#  Prediction(uid='671', iid='628', r_ui=3.0, est=3.5052932077980623, details={'was_impossible': False}),
#  Prediction(uid='637', iid='544', r_ui=3.0, est=2.291492153569366, details={'was_impossible': False}),
#  Prediction(uid='504', iid='529', r_ui=4.0, est=4.1434083697043524, details={'was_impossible': False}),
#  Prediction(uid='321', iid='9', r_ui=4.0, est=3.408751740992091, details={'was_impossible': False}),
#  Prediction(uid='234', iid='589', r_ui=3.0, est=3.518546331878978, details={'was_impossible': False}),
#  Prediction(uid='174', iid='143', r_ui=5.0, est=3.8381752913904523, details={'was_impossible': False}),
#  Prediction(uid='429', iid='180', r_ui=5.0, est=4.139754371189308, details={'was_impossible': False}),
#  Prediction(uid='44', iid='176', r_ui=5.0, est=4.188193125799594, details={'was_impossible': False}),
#  Prediction(uid='1', iid='37', r_ui=2.0, est=3.0982320676315753, details={'was_impossible': False}),
#  Prediction(uid='836', iid='793', r_ui=2.0, est=3.599748311505471, details={'was_impossible': False}),
#  Prediction(uid='429', iid='150', r_ui=5.0, est=3.6252056158761286, details={'was_impossible': False}),
#  Prediction(uid='409', iid='8', r_ui=3.0, est=3.459134350204008, details={'was_impossible': False}),
#  Prediction(uid='494', iid='64', r_ui=5.0, est=4.415536040162191, details={'was_impossible': False}),
#  Prediction(uid='446', iid='303', r_ui=2.0, est=3.35812459395188, details={'was_impossible': False}),
#  Prediction(uid='117', iid='977', r_ui=3.0, est=3.1805582729174504, details={'was_impossible': False}),
#  Prediction(uid='590', iid='275', r_ui=4.0, est=3.935785048091132, details={'was_impossible': False}),
#  Prediction(uid='64', iid='1141', r_ui=5.0, est=3.436448254268713, details={'was_impossible': False}),
#  Prediction(uid='927', iid='25', r_ui=3.0, est=3.6119029870067236, details={'was_impossible': False}),
#  Prediction(uid='339', iid='180', r_ui=5.0, est=4.51332718725868, details={'was_impossible': False}),
#  Prediction(uid='870', iid='98', r_ui=4.0, est=3.9331303302600875, details={'was_impossible': False}),
#  Prediction(uid='95', iid='622', r_ui=4.0, est=3.034140318394273, details={'was_impossible': False}),
#  Prediction(uid='290', iid='1035', r_ui=4.0, est=2.867886949655366, details={'was_impossible': False}),
#  Prediction(uid='853', iid='333', r_ui=4.0, est=3.35442876337837, details={'was_impossible': False}),
#  Prediction(uid='303', iid='155', r_ui=3.0, est=2.6929829113465833, details={'was_impossible': False}),
#  Prediction(uid='867', iid='98', r_ui=5.0, est=4.884788779310371, details={'was_impossible': False}),
#  Prediction(uid='326', iid='174', r_ui=4.0, est=4.072982397599651, details={'was_impossible': False}),
#  Prediction(uid='885', iid='239', r_ui=3.0, est=3.5422241898378326, details={'was_impossible': False}),
#  Prediction(uid='194', iid='1410', r_ui=2.0, est=2.928781715703659, details={'was_impossible': False}),
#  Prediction(uid='144', iid='1012', r_ui=4.0, est=3.3448127001436463, details={'was_impossible': False}),
#  Prediction(uid='537', iid='378', r_ui=2.0, est=2.5564093505867658, details={'was_impossible': False}),
#  Prediction(uid='90', iid='187', r_ui=4.0, est=4.5953656255964015, details={'was_impossible': False}),
#  Prediction(uid='56', iid='228', r_ui=3.0, est=4.2470798023738645, details={'was_impossible': False}),
#  Prediction(uid='206', iid='269', r_ui=4.0, est=2.65311214189627, details={'was_impossible': False}),
#  Prediction(uid='221', iid='809', r_ui=3.0, est=3.1227490351483844, details={'was_impossible': False}),
#  Prediction(uid='354', iid='419', r_ui=4.0, est=3.5562979690889143, details={'was_impossible': False}),
#  Prediction(uid='758', iid='715', r_ui=4.0, est=3.985921037147689, details={'was_impossible': False}),
#  Prediction(uid='246', iid='77', r_ui=2.0, est=2.529106101588255, details={'was_impossible': False}),
#  Prediction(uid='854', iid='535', r_ui=3.0, est=2.567213951136261, details={'was_impossible': False}),
#  Prediction(uid='588', iid='73', r_ui=3.0, est=3.8440367361913514, details={'was_impossible': False}),
#  Prediction(uid='608', iid='328', r_ui=4.0, est=3.3747407004883865, details={'was_impossible': False}),
#  Prediction(uid='506', iid='715', r_ui=2.0, est=3.0688048482837385, details={'was_impossible': False}),
#  Prediction(uid='442', iid='231', r_ui=3.0, est=2.5410426436444773, details={'was_impossible': False}),
#  Prediction(uid='654', iid='591', r_ui=5.0, est=3.7906212610118972, details={'was_impossible': False}),
#  Prediction(uid='308', iid='826', r_ui=3.0, est=2.7420441236759636, details={'was_impossible': False}),
#  Prediction(uid='254', iid='624', r_ui=2.0, est=2.948123543775037, details={'was_impossible': False}),
#  Prediction(uid='747', iid='274', r_ui=4.0, est=3.4051167677449103, details={'was_impossible': False}),
#  Prediction(uid='199', iid='1', r_ui=1.0, est=3.011608315566616, details={'was_impossible': False}),
#  Prediction(uid='275', iid='142', r_ui=2.0, est=2.8521152775633296, details={'was_impossible': False}),
#  Prediction(uid='130', iid='746', r_ui=5.0, est=4.144636759082513, details={'was_impossible': False}),
#  Prediction(uid='360', iid='661', r_ui=5.0, est=4.048710430069754, details={'was_impossible': False}),
#  Prediction(uid='684', iid='728', r_ui=2.0, est=3.1523837002539805, details={'was_impossible': False}),
#  Prediction(uid='21', iid='217', r_ui=3.0, est=3.0543718694711774, details={'was_impossible': False}),
#  Prediction(uid='561', iid='159', r_ui=1.0, est=2.6566055250575307, details={'was_impossible': False}),
#  Prediction(uid='399', iid='343', r_ui=2.0, est=2.740034333225406, details={'was_impossible': False}),
#  Prediction(uid='804', iid='636', r_ui=3.0, est=3.567606405757068, details={'was_impossible': False}),
#  Prediction(uid='615', iid='192', r_ui=5.0, est=4.172193128725168, details={'was_impossible': False}),
#  Prediction(uid='518', iid='237', r_ui=4.0, est=4.226334560830426, details={'was_impossible': False}),
#  Prediction(uid='886', iid='227', r_ui=3.0, est=3.2183958386216083, details={'was_impossible': False}),
#  Prediction(uid='749', iid='1337', r_ui=3.0, est=3.079798762233769, details={'was_impossible': False}),
#  Prediction(uid='548', iid='302', r_ui=4.0, est=4.232666580459358, details={'was_impossible': False}),
#  Prediction(uid='454', iid='419', r_ui=4.0, est=3.308427506067202, details={'was_impossible': False}),
#  Prediction(uid='886', iid='232', r_ui=3.0, est=3.198773879843087, details={'was_impossible': False}),
#  Prediction(uid='698', iid='300', r_ui=4.0, est=3.0884306399583155, details={'was_impossible': False}),
#  Prediction(uid='472', iid='443', r_ui=4.0, est=4.651045785885202, details={'was_impossible': False}),
#  Prediction(uid='218', iid='176', r_ui=5.0, est=3.7935527231452815, details={'was_impossible': False}),
#  Prediction(uid='621', iid='313', r_ui=5.0, est=4.281761520689988, details={'was_impossible': False}),
#  Prediction(uid='456', iid='218', r_ui=4.0, est=3.3671557964801067, details={'was_impossible': False}),
#  Prediction(uid='279', iid='919', r_ui=3.0, est=3.3197179197547717, details={'was_impossible': False}),
#  Prediction(uid='117', iid='109', r_ui=4.0, est=3.939213308045116, details={'was_impossible': False}),
#  Prediction(uid='934', iid='297', r_ui=5.0, est=4.086467700013013, details={'was_impossible': False}),
#  Prediction(uid='936', iid='268', r_ui=4.0, est=4.218822331957614, details={'was_impossible': False}),
#  Prediction(uid='263', iid='419', r_ui=5.0, est=4.168180904885456, details={'was_impossible': False}),
#  Prediction(uid='498', iid='109', r_ui=3.0, est=2.968438370728466, details={'was_impossible': False}),
#  Prediction(uid='253', iid='751', r_ui=3.0, est=3.3668530145609212, details={'was_impossible': False}),
#  Prediction(uid='2', iid='305', r_ui=3.0, est=3.691994370973052, details={'was_impossible': False}),
#  Prediction(uid='379', iid='405', r_ui=3.0, est=3.1886500272390865, details={'was_impossible': False}),
#  Prediction(uid='213', iid='100', r_ui=5.0, est=4.45476541479403, details={'was_impossible': False}),
#  Prediction(uid='175', iid='566', r_ui=3.0, est=3.4180122642793833, details={'was_impossible': False}),
#  Prediction(uid='222', iid='446', r_ui=3.0, est=2.4453385373275953, details={'was_impossible': False}),
#  Prediction(uid='465', iid='478', r_ui=4.0, est=3.649278954128595, details={'was_impossible': False}),
#  Prediction(uid='94', iid='380', r_ui=3.0, est=3.2205010553555278, details={'was_impossible': False}),
#  Prediction(uid='758', iid='1034', r_ui=4.0, est=2.783373077617836, details={'was_impossible': False}),
#  ...]

# %%
accuracy.rmse(predictions)
# Out:
# RMSE: 0.9389
# 0.938946392530948

# %%
def get_mrr(surprise_predictions, k_highest_scores=None):    
    from sklearn.metrics import label_ranking_average_precision_score
    from scipy import sparse
    
    uids = np.array([p.uid for p in surprise_predictions]).astype(np.int)
    iids = np.array([p.iid for p in surprise_predictions]).astype(np.int)

    # 三分以上判斷為相關 低於三分判斷為不相關
    r_uis = np.array([1 if p.r_ui >= 3 else 0 for p in surprise_predictions]).astype(np.float)
    r_uis = np.asarray(r_uis)        
    ests = np.array([p.est for p in surprise_predictions]).astype(np.float)

    sparse_preds = sparse.coo_matrix((ests, (uids ,iids)))
    sparse_vals = sparse.coo_matrix((r_uis, (uids ,iids)))
    
    dense_preds = sparse_preds.toarray()
    dense_vals = sparse_vals.toarray()  
    def cal_mrr(y_true, y_score):
        mrr_list = []
        for i in range(len(y_score)):
            rank = np.argsort(y_score[i])[::-1]
            pos = 0
            for r in rank:
                pos += 1
                if y_true[i][r] == 1:
                    rr = 1/pos
                    mrr_list.append(rr) 
                    break
        return sum(mrr_list)/len(mrr_list)
    return cal_mrr(y_true=dense_vals, y_score=dense_preds)

# %%
get_mrr(predictions)
# Out:
# 0.9690298507462688

# %%
def get_map(surprise_predictions, k_highest_scores=None):    
    from sklearn.metrics import label_ranking_average_precision_score
    from scipy import sparse
    
    uids = np.array([p.uid for p in surprise_predictions ]).astype(np.int)
    iids = np.array([p.iid for p in surprise_predictions ]).astype(np.int)
    # 三分以上判斷為相關 低於三分判斷為不相關
    r_uis = np.array([1 if p.r_ui >= 3 else 0 for p in surprise_predictions]).astype(np.float)
    ests = np.array([p.est for p in surprise_predictions ]).astype(np.float)

    sparse_preds = sparse.coo_matrix((ests, (uids ,iids )))
    sparse_vals = sparse.coo_matrix((r_uis, (uids ,iids )))
    
    dense_preds = sparse_preds.toarray()
    dense_vals = sparse_vals.toarray()    
    return label_ranking_average_precision_score(y_true= dense_vals, y_score= dense_preds)

# %%
get_map(predictions)
# Out:
# 0.9276755135860559

# %%
def get_ndcg(surprise_predictions, k_highest_scores=None):
    
    from sklearn.metrics import ndcg_score
    from scipy import sparse
    
    uids = np.array([p.uid for p in surprise_predictions ]).astype(np.int)
    iids = np.array([p.iid for p in surprise_predictions ]).astype(np.int)
    r_uis = np.array([p.r_ui for p in surprise_predictions ]).astype(np.float)
    ests = np.array([p.est for p in surprise_predictions ]).astype(np.float)

    sparse_preds = sparse.coo_matrix((ests, (uids ,iids )))
    sparse_vals = sparse.coo_matrix((r_uis, (uids ,iids )))
    
    dense_preds = sparse_preds.toarray()
    dense_vals = sparse_vals.toarray()    
    return ndcg_score(y_true= dense_vals , y_score= dense_preds, k=k_highest_scores)

# %%
get_ndcg(predictions)
# Out:
# 0.9524153626409766
